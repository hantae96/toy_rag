# %%
from pathlib import Path
import pandas as pd

DOCS_DIR_PATH = Path().resolve().parent/"docs"

# %%
file_path = DOCS_DIR_PATH/"doc_text_lengths.csv"

df = pd.read_csv(file_path)

file_path
# Out:
# WindowsPath('C:/Users/IT/Desktop/study/python/project/docs/doc_text_lengths.csv')

# %%
df["clean_text_length"].describe()
# Out:
# count      337.000000
# mean      2286.525223
# std       5728.459917
# min         37.000000
# 25%        658.000000
# 50%        996.000000
# 75%       1694.000000
# max      68383.000000
# Name: clean_text_length, dtype: float64

# %%
df[df["clean_text_length"] == 68383]["doc_id"]
# Out:
# 0    1043
# Name: doc_id, dtype: int64
