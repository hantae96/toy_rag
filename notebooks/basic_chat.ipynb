# %% [markdown]
# # Basic LLM Chat
#
# `.env`에 `OPENAI_API_KEY`가 들어 있다고 가정하고 가장 간단하게 한 번 질문하고 답을 받는 예제입니다.

# %%
import os

from dotenv import load_dotenv

load_dotenv()

if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("OPENAI_API_KEY가 .env에 없습니다.")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
question = "파이썬이 왜 RAG 프로토타이핑에 자주 쓰이는지 3문장으로 설명해줘."
response = llm.invoke(question)

print(response.content)
# Out:
# 파이썬은 간결하고 직관적인 문법 덕분에 빠른 프로토타이핑이 가능하여 RAG(Research, Analysis, and Generation) 작업에 적합합니다. 또한, 풍부한 라이브러리와 프레임워크(예: NumPy, Pandas, TensorFlow 등)를 통해 데이터 처리 및 분석을 효율적으로 수행할 수 있습니다. 마지막으로, 파이썬은 커뮤니티가 활발하여 다양한 자료와 지원을 쉽게 찾을 수 있어 개발 속도를 더욱 높여줍니다.
